# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
df = pd.read_csv("log_0004_2020-01-28_15-31_One-Server-with-error.csv", sep = ";", error_bad_lines=False)
df.head(10)
# Out:
#        Time                                             Server Message_type  \
# 0  0.313867       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 1  0.443005       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 2  0.473785  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
# 3  0.604733       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 4  0.674257       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 5  0.729618  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
# 6  0.838336       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 7  0.966205       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 8  0.982906       payment#457f06b8-204a-4f13-ac01-e717a628c86b         INFO
# 9  0.989413  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
#
#    CPU Usage  Memory Usage   Latency                        Transaction_ID  \
# 0   0.013333      0.001333  0.177338  cc7151dd-6dca-4435-9462-43c71679a606
# 1   0.026667      0.002667  0.279902  941affdd-fc4f-41fd-b89a-f4c5d8693682
# 2   0.020000      0.002000  0.286613  cc7151dd-6dca-4435-9462-43c71679a606
# 3   0.046667      0.004667  0.542260  66203d7c-4d36-41f8-8504-d72416e2c731
# 4   0.053333      0.005333  0.621217  f97c1692-5efa-41b5-bddd-003bf9fb8f87
# 5   0.040000      0.004000  0.485460  941affdd-fc4f-41fd-b89a-f4c5d8693682
# 6   0.066667      0.006667  0.728158  cc7151dd-6dca-4435-9462-43c71679a606
# 7   0.066667      0.006667  0.754767  3684b8d9-db1b-42fc-a500-90062a814898
# 8   0.010000      0.001000  0.144570  cc7151dd-6dca-4435-9462-43c71679a606
# 9   0.040000      0.004000  0.487759  66203d7c-4d36-41f8-8504-d72416e2c731
#
#                                          From_Server  \
# 0                                             client
# 1                                             client
# 2       balance#09776368-b978-43f6-a0df-3f6f7b565223
# 3                                             client
# 4                                             client
# 5       balance#09776368-b978-43f6-a0df-3f6f7b565223
# 6  authentication#3b607c24-0e63-4752-8892-a1cf9fe...
# 7                                             client
# 8       balance#09776368-b978-43f6-a0df-3f6f7b565223
# 9       balance#09776368-b978-43f6-a0df-3f6f7b565223
#
#                                              Message
# 0  Requesting balance#09776368-b978-43f6-a0df-3f6...
# 1  Requesting balance#09776368-b978-43f6-a0df-3f6...
# 2  Requesting authentication#3b607c24-0e63-4752-8...
# 3  Requesting balance#09776368-b978-43f6-a0df-3f6...
# 4  Requesting balance#09776368-b978-43f6-a0df-3f6...
# 5  Requesting authentication#3b607c24-0e63-4752-8...
# 6  Requesting balance#09776368-b978-43f6-a0df-3f6...
# 7  Requesting balance#09776368-b978-43f6-a0df-3f6...
# 8  Requesting payment#457f06b8-204a-4f13-ac01-e71...
# 9  Requesting authentication#3b607c24-0e63-4752-8...

# %%
# Split dataframe into three dataframes based on Server
df = df.drop(["Transaction_ID","From_Server", "Message"], axis=1)
df.head(10)
# Out:
#        Time                                             Server Message_type  \
# 0  0.313867       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 1  0.443005       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 2  0.473785  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
# 3  0.604733       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 4  0.674257       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 5  0.729618  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
# 6  0.838336       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 7  0.966205       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 8  0.982906       payment#457f06b8-204a-4f13-ac01-e717a628c86b         INFO
# 9  0.989413  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
#
#    CPU Usage  Memory Usage   Latency
# 0   0.013333      0.001333  0.177338
# 1   0.026667      0.002667  0.279902
# 2   0.020000      0.002000  0.286613
# 3   0.046667      0.004667  0.542260
# 4   0.053333      0.005333  0.621217
# 5   0.040000      0.004000  0.485460
# 6   0.066667      0.006667  0.728158
# 7   0.066667      0.006667  0.754767
# 8   0.010000      0.001000  0.144570
# 9   0.040000      0.004000  0.487759

# %%
# Reset index
df = df.reset_index()
df = df.drop(["index"], axis=1)
df.head(10)
# Out:
#        Time                                             Server Message_type  \
# 0  0.313867       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 1  0.443005       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 2  0.473785  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
# 3  0.604733       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 4  0.674257       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 5  0.729618  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
# 6  0.838336       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 7  0.966205       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 8  0.982906       payment#457f06b8-204a-4f13-ac01-e717a628c86b         INFO
# 9  0.989413  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
#
#    CPU Usage  Memory Usage   Latency
# 0   0.013333      0.001333  0.177338
# 1   0.026667      0.002667  0.279902
# 2   0.020000      0.002000  0.286613
# 3   0.046667      0.004667  0.542260
# 4   0.053333      0.005333  0.621217
# 5   0.040000      0.004000  0.485460
# 6   0.066667      0.006667  0.728158
# 7   0.066667      0.006667  0.754767
# 8   0.010000      0.001000  0.144570
# 9   0.040000      0.004000  0.487759

# %%
# Convert Time from seconds to minutes and name the new time Time_floor
#df["Time"]=df["Time"].div(60)
df["Time_floor"] = np.floor(df["Time"]).astype("int")
df.head(10)
# Out:
#        Time                                             Server Message_type  \
# 0  0.313867       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 1  0.443005       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 2  0.473785  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
# 3  0.604733       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 4  0.674257       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 5  0.729618  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
# 6  0.838336       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 7  0.966205       balance#09776368-b978-43f6-a0df-3f6f7b565223         INFO
# 8  0.982906       payment#457f06b8-204a-4f13-ac01-e717a628c86b         INFO
# 9  0.989413  authentication#3b607c24-0e63-4752-8892-a1cf9fe...         INFO
#
#    CPU Usage  Memory Usage   Latency  Time_floor
# 0   0.013333      0.001333  0.177338           0
# 1   0.026667      0.002667  0.279902           0
# 2   0.020000      0.002000  0.286613           0
# 3   0.046667      0.004667  0.542260           0
# 4   0.053333      0.005333  0.621217           0
# 5   0.040000      0.004000  0.485460           0
# 6   0.066667      0.006667  0.728158           0
# 7   0.066667      0.006667  0.754767           0
# 8   0.010000      0.001000  0.144570           0
# 9   0.040000      0.004000  0.487759           0

# %%
# Only select rows with Message_type equal to INFO
#df = df.loc[df["Message_type"] == "INFO"]
# Only select rows with Message_type equal to ERROR
#df = df.loc[df["Message_type"] == "ERROR"]

# %%
# Group rows by Server and Time_floor; drop obsolete Time column
df_grouped = df.groupby(["Server","Time_floor","Message_type"], as_index=False).mean()
df_grouped = df_grouped.drop(["Time"], axis=1)
df_grouped
# Out:
#                                                 Server  Time_floor  \
# 0    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 1    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           1
# 2    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           2
# 3    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           3
# 4    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           4
# ..                                                 ...         ...
# 394       payment#457f06b8-204a-4f13-ac01-e717a628c86b          95
# 395       payment#457f06b8-204a-4f13-ac01-e717a628c86b          96
# 396       payment#457f06b8-204a-4f13-ac01-e717a628c86b          97
# 397       payment#457f06b8-204a-4f13-ac01-e717a628c86b          98
# 398       payment#457f06b8-204a-4f13-ac01-e717a628c86b          99
#
#     Message_type  CPU Usage  Memory Usage   Latency
# 0           INFO   0.033333      0.003333  0.419944
# 1           INFO   0.065000      0.006500  0.706356
# 2           INFO   0.092500      0.009250  0.966290
# 3           INFO   0.130000      0.013000  1.363681
# 4           INFO   0.172000      0.017200  1.804405
# ..           ...        ...           ...       ...
# 394        ERROR   0.975714      0.097571  9.816336
# 395        ERROR   0.967778      0.096778  9.732343
# 396        ERROR   0.953333      0.095333  9.577608
# 397        ERROR   0.972727      0.097273  9.777966
# 398        ERROR   0.989000      0.098900  9.943246
#
# [399 rows x 6 columns]

# %%
# Unpivot dataframe from wide format to long format
df_melt = pd.melt(df_grouped, id_vars = ["Server", "Time_floor","Message_type"], 
                  value_vars = ["CPU Usage","Memory Usage","Latency"], 
                  value_name = "Value")

# %%
# Sort dataframe by Server and Time_floor
df_melt = df_melt.sort_values(by=["Server", "Time_floor"])
df_melt.tail(20)
# Out:
#                                             Server  Time_floor Message_type  \
# 791   payment#457f06b8-204a-4f13-ac01-e717a628c86b          93        ERROR
# 1190  payment#457f06b8-204a-4f13-ac01-e717a628c86b          93        ERROR
# 393   payment#457f06b8-204a-4f13-ac01-e717a628c86b          94        ERROR
# 792   payment#457f06b8-204a-4f13-ac01-e717a628c86b          94        ERROR
# 1191  payment#457f06b8-204a-4f13-ac01-e717a628c86b          94        ERROR
# 394   payment#457f06b8-204a-4f13-ac01-e717a628c86b          95        ERROR
# 793   payment#457f06b8-204a-4f13-ac01-e717a628c86b          95        ERROR
# 1192  payment#457f06b8-204a-4f13-ac01-e717a628c86b          95        ERROR
# 395   payment#457f06b8-204a-4f13-ac01-e717a628c86b          96        ERROR
# 794   payment#457f06b8-204a-4f13-ac01-e717a628c86b          96        ERROR
# 1193  payment#457f06b8-204a-4f13-ac01-e717a628c86b          96        ERROR
# 396   payment#457f06b8-204a-4f13-ac01-e717a628c86b          97        ERROR
# 795   payment#457f06b8-204a-4f13-ac01-e717a628c86b          97        ERROR
# 1194  payment#457f06b8-204a-4f13-ac01-e717a628c86b          97        ERROR
# 397   payment#457f06b8-204a-4f13-ac01-e717a628c86b          98        ERROR
# 796   payment#457f06b8-204a-4f13-ac01-e717a628c86b          98        ERROR
# 1195  payment#457f06b8-204a-4f13-ac01-e717a628c86b          98        ERROR
# 398   payment#457f06b8-204a-4f13-ac01-e717a628c86b          99        ERROR
# 797   payment#457f06b8-204a-4f13-ac01-e717a628c86b          99        ERROR
# 1196  payment#457f06b8-204a-4f13-ac01-e717a628c86b          99        ERROR
#
#           variable     Value
# 791   Memory Usage  0.096889
# 1190       Latency  9.766642
# 393      CPU Usage  0.984545
# 792   Memory Usage  0.098455
# 1191       Latency  9.895827
# 394      CPU Usage  0.975714
# 793   Memory Usage  0.097571
# 1192       Latency  9.816336
# 395      CPU Usage  0.967778
# 794   Memory Usage  0.096778
# 1193       Latency  9.732343
# 396      CPU Usage  0.953333
# 795   Memory Usage  0.095333
# 1194       Latency  9.577608
# 397      CPU Usage  0.972727
# 796   Memory Usage  0.097273
# 1195       Latency  9.777966
# 398      CPU Usage  0.989000
# 797   Memory Usage  0.098900
# 1196       Latency  9.943246

# %%
# Sort dataframe by Server and Time_floor
df_melt_sorted = df_melt.sort_values(by=["Server", "Time_floor"])
df_melt_sorted.head(20)
# Out:
#                                                 Server  Time_floor  \
# 0    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 399  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 798  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 1    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           1
# 400  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           1
# 799  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           1
# 2    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           2
# 401  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           2
# 800  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           2
# 3    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           3
# 402  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           3
# 801  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           3
# 4    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           4
# 403  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           4
# 802  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           4
# 5    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           5
# 404  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           5
# 803  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           5
# 6    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           6
# 405  authentication#3b607c24-0e63-4752-8892-a1cf9fe...           6
#
#     Message_type      variable     Value
# 0           INFO     CPU Usage  0.033333
# 399         INFO  Memory Usage  0.003333
# 798         INFO       Latency  0.419944
# 1           INFO     CPU Usage  0.065000
# 400         INFO  Memory Usage  0.006500
# 799         INFO       Latency  0.706356
# 2           INFO     CPU Usage  0.092500
# 401         INFO  Memory Usage  0.009250
# 800         INFO       Latency  0.966290
# 3           INFO     CPU Usage  0.130000
# 402         INFO  Memory Usage  0.013000
# 801         INFO       Latency  1.363681
# 4           INFO     CPU Usage  0.172000
# 403         INFO  Memory Usage  0.017200
# 802         INFO       Latency  1.804405
# 5           INFO     CPU Usage  0.214000
# 404         INFO  Memory Usage  0.021400
# 803         INFO       Latency  2.233680
# 6           INFO     CPU Usage  0.240000
# 405         INFO  Memory Usage  0.024000

# %%
# Make two separate dataframes to filter by INFO and ERROR
df_info = df_melt_sorted.loc[df_melt_sorted["Message_type"] == "INFO"]
df_error = df_melt_sorted.loc[df_melt_sorted["Message_type"] == "ERROR"]

# %%
# Check if ERROR is not NA
df_error = df_error.groupby(['Server','Time_floor']).first().reset_index()

# %%
df_error = df_error.loc[df_error["Server"].notnull()]

# %%
# Add a column which counts the rolling number of errors and makes sure to group the count by server
df_error["Error_count"] = df_error["Message_type"].eq("ERROR")

# %%
df_error["Error_count"] = df_error.groupby('Server')["Error_count"].transform(pd.Series.cumsum)

# %%
# Merge both dataframes per Server and Time
df_info = df_info.drop(["Message_type"], axis=1)
df_error = df_error.drop(["Message_type"], axis=1)
df_result = pd.merge(df_info, df_error, how = 'outer', on = ['Server','Time_floor'])
df_result
# Out:
#                                                 Server  Time_floor  \
# 0    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 1    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 2    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 3    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           1
# 4    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           1
# ..                                                 ...         ...
# 655       payment#457f06b8-204a-4f13-ac01-e717a628c86b          95
# 656       payment#457f06b8-204a-4f13-ac01-e717a628c86b          96
# 657       payment#457f06b8-204a-4f13-ac01-e717a628c86b          97
# 658       payment#457f06b8-204a-4f13-ac01-e717a628c86b          98
# 659       payment#457f06b8-204a-4f13-ac01-e717a628c86b          99
#
#        variable_x   Value_x variable_y   Value_y  Error_count
# 0       CPU Usage  0.033333        NaN       NaN          NaN
# 1    Memory Usage  0.003333        NaN       NaN          NaN
# 2         Latency  0.419944        NaN       NaN          NaN
# 3       CPU Usage  0.065000        NaN       NaN          NaN
# 4    Memory Usage  0.006500        NaN       NaN          NaN
# ..            ...       ...        ...       ...          ...
# 655           NaN       NaN  CPU Usage  0.975714         49.0
# 656           NaN       NaN  CPU Usage  0.967778         50.0
# 657           NaN       NaN  CPU Usage  0.953333         51.0
# 658           NaN       NaN  CPU Usage  0.972727         52.0
# 659           NaN       NaN  CPU Usage  0.989000         53.0
#
# [660 rows x 7 columns]

# %%
# Change names of dataframe columns
#df_final = df_result.drop(["variable_y","Value_y"], axis=1)
#df_final.columns = ['Server', 'Time_floor', 'variable', 'Value', 'Error_count']
df_result.to_excel("Manual_Log_Filtered_Final.xlsx")

# %%
# Formula to start the count at  for every server
server_names = df_final["Server"].unique()
for server in server_names:
    # Get index of first occurance
    server_index=  df_final.loc[(df_final["Server"] == server)].first_valid_index()
    df_final.loc[(df_final.index == server_index) & (df_final["Error_count"].isna()),"Error_count" ] = 0

# %%
# Fill in NA values i Error_count with the preceding value to have a rolling count
df_final = df_final.fillna(method='ffill')
df_final
# Out:
#                                                 Server  Time_floor  \
# 0    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 1    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 2    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           0
# 3    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           1
# 4    authentication#3b607c24-0e63-4752-8892-a1cf9fe...           1
# ..                                                 ...         ...
# 655       payment#457f06b8-204a-4f13-ac01-e717a628c86b          95
# 656       payment#457f06b8-204a-4f13-ac01-e717a628c86b          96
# 657       payment#457f06b8-204a-4f13-ac01-e717a628c86b          97
# 658       payment#457f06b8-204a-4f13-ac01-e717a628c86b          98
# 659       payment#457f06b8-204a-4f13-ac01-e717a628c86b          99
#
#          variable     Value  Error_count
# 0       CPU Usage  0.033333          0.0
# 1    Memory Usage  0.003333          0.0
# 2         Latency  0.419944          0.0
# 3       CPU Usage  0.065000          0.0
# 4    Memory Usage  0.006500          0.0
# ..            ...       ...          ...
# 655       Latency  5.712217         49.0
# 656       Latency  5.712217         50.0
# 657       Latency  5.712217         51.0
# 658       Latency  5.712217         52.0
# 659       Latency  5.712217         53.0
#
# [660 rows x 5 columns]

# %%
# Save dataframe
df_final.to_csv("Manual_Log_Filtered_Final.csv")
df_final.to_excel("Manual_Log_Filtered_Final.xlsx")
